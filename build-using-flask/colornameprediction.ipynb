# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('colorName.csv')

# %%
df.head()
# Out:
#                   name1                  name2      hex  red  green  blue
# 0    air_force_blue_raf   Air Force Blue (Raf)  #5d8aa8   93    138   168
# 1   air_force_blue_usaf  Air Force Blue (Usaf)  #00308f    0     48   143
# 2  air_superiority_blue   Air Superiority Blue  #72a0c1  114    160   193
# 3       alabama_crimson        Alabama Crimson  #a32638  163     38    56
# 4            alice_blue             Alice Blue  #f0f8ff  240    248   255

# %%
X,y = df[['red','green','blue']],df['name2']

# %%
X.head()
# Out:
#    red  green  blue
# 0   93    138   168
# 1    0     48   143
# 2  114    160   193
# 3  163     38    56
# 4  240    248   255

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(n_neighbors=1)

# %%
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
test=[253,150,50]

# %%
model.predict([test])[0]
# Out:
# c:\Users\VINITHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 'Deep Saffron'

# %%
import pickle
# open a file, where you ant to store the data
file = open('color.pkl', 'wb')
# dump information to that file
pickle.dump(model, file)

# %%
model = pickle.load(open('color.pkl','rb'))

# %%
model
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
with open('color.pkl', 'rb') as f:
    data = pickle.load(f)

# Now, you can work with the loaded data
print(data)
# Out:
# KNeighborsClassifier(n_neighbors=1)
